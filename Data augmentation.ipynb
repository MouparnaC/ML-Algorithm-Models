# %% [markdown]
# # Task 1: Import Libraries

# %%
# %matplotlib inline
import os
import numpy as np
import tensorflow as tf

from PIL import Image
from matplotlib import pyplot as plt

print('Using TensorFlow', tf.__version__)
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow 2.10.0

# %% [markdown]
# # Task 2: Rotation

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40)

img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %% [markdown]
# # Task 3: Width and Height Shifts

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    width_shift_range = [-100, -50, 0, 50, 100],
    height_shift_range = [-50, 0, 50]
)
img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %% [markdown]
# # Task 4: Brightness

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    brightness_range = (0.5, 2)
)
img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %% [markdown]
# # Task 5: Shear Transformation

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    # Your code here
    shear_range=40
)
img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %% [markdown]
# # Task 6: Zoom

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    zoom_range = 0.5
)

img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %% [markdown]
# # Task 7: Channel Shift

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    channel_shift_range = 100
)
img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %% [markdown]
# # Task 8: Flips

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    horizontal_flip = True,
    vertical_flip = True,
    rotation_range = 30
)
img = tf.keras.utils.load_img('cat.jpg')
x = tf.keras.utils.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
aug_iter=datagen.flow(x, batch_size=1,save_to_dir='Videos', save_prefix='cat', save_format='jpeg')
# generate batch of images
for i in range(3):
    # convert to unsigned integers
    image = next(aug_iter)[0].astype('uint8')
 
    # plot image
    ax[i].imshow(image)
    ax[i].axis('off')

# %%
x.shape
# Out:
# (1, 400, 600, 3)

# %%
type(x)
# Out:
# numpy.ndarray
